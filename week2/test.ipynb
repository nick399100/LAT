# %% [markdown]
# #想要把第一個CSV檔讀入

# %%
import pandas as pd

df = pd.read_csv('test DATA.csv')

print(df.to_string())
# Out:
#              統計期         總計        汽車     大客車 大客車 /自用  大客車 /營業  大客車 /營業 /遊覽車  大客車 /營業 /營業（不含遊覽車）      大貨車  大貨車 /自用  大貨車 /營業       小客車   小客車 /自用  小客車 /營業  小客車 /營業 /租賃  小客車 /營業 /計程車 小客車 /營業 /其他營業小客車      小貨車  小貨車 /自用  小貨車 /營業  小貨車 /營業 /租賃  小貨車 /營業 /營業（不含租賃）     特種車   警備車    救護車   消防車    郵車      其他         機車       機車重型     大型重型  大型重型550cc以上  大型重型未滿550cc      普通重型     機車輕型 小型輕型     普通輕型
# 0           107年  1290511.0  435114.0  1951.0     96    1855.0         759.0              1096.0   8640.0   3997.0   4643.0  384083.0  338308.0  45775.0      41045.0        4730.0                -  36752.0  28072.0   8680.0       6658.0             2022.0  3688.0   80   205.0  102   354   2947.0   855397.0   844402.0  16569.0       8036.0       8533.0  827833.0  10995.0    -  10995.0
# ...

# %%
df
# Out:
#         統計期         總計        汽車     大客車 大客車 /自用  大客車 /營業  大客車 /營業 /遊覽車  \
# 0      107年  1290511.0  435114.0  1951.0     96    1855.0         759.0
# 1   107年 1月   116803.0   47937.0   102.0      5      97.0          61.0
# 2   107年 2月    75035.0   26964.0   128.0      2     126.0          63.0
# 3   107年 3月   120094.0   39260.0   240.0      6     234.0          96.0
# 4   107年 4月    93358.0   34457.0   164.0      8     156.0          85.0
# ..      ...        ...       ...     ...     ...      ...           ...
# 65      NaN        NaN       NaN     NaN     NaN      NaN           NaN
# 66      NaN        NaN       NaN     NaN     NaN      NaN           NaN
# 67      NaN        NaN       NaN     NaN     NaN      NaN           NaN
# 68      NaN        NaN       NaN     NaN     NaN      NaN           NaN
# 69      NaN        NaN       NaN     NaN     NaN      NaN           NaN
#
#     大客車 /營業 /營業（不含遊覽車）     大貨車  大貨車 /自用  ...      其他        機車      機車重型  \
# ...

# %%
temp = df[['統計期','總計','機車']]
temp
# Out:
#         統計期         總計        機車
# 0      107年  1290511.0  855397.0
# 1   107年 1月   116803.0   68866.0
# 2   107年 2月    75035.0   48071.0
# 3   107年 3月   120094.0   80834.0
# 4   107年 4月    93358.0   58901.0
# ..      ...        ...       ...
# 65      NaN        NaN       NaN
# 66      NaN        NaN       NaN
# 67      NaN        NaN       NaN
# 68      NaN        NaN       NaN
# 69      NaN        NaN       NaN
#
# [70 rows x 3 columns]

# %%
Type = temp.groupby(['機車'])[''].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38456\1500439068.py in <module>
# ----> 1 Type = temp.groupby(['機車'])['機車'].sum().reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1492
#    1493             df = self.to_frame(name)
# -> 1494             return df.reset_index(level=level, drop=drop)
#    1495
#    1496     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...
