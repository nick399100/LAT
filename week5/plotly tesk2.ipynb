# %% [markdown]
# ## 使用mapbox 來顯示可視覺化地圖

# %%
import pandas as pd
df = pd.read_csv('taskdata2.csv',encoding = 'ANSI')
import plotly.express as px
px.set_mapbox_access_token('pk.eyJ1IjoibmljazM5OTEwMCIsImEiOiJjbGZwNzM5Z3MwOGh0M3BvYmQ1YXFsNzNrIn0.PAL5bwLCSwghjY5jBNGUCQ')
fig = px.scatter_mapbox(df, lat='lat', lon='lon',size='學校小計',hover_name='schoolname',hover_data=["學校小計", "5年內設備數量", "5年以上設備數量"], zoom=10)
fig.show()
# Out:
# <div>                            <div id="d895e5d3-e1ee-481f-8a76-08d116a17e0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d895e5d3-e1ee-481f-8a76-08d116a17e0c")) {                    Plotly.newPlot(                        "d895e5d3-e1ee-481f-8a76-08d116a17e0c",                        [{"customdata":[[209,22,187],[415,216,199],[250,221,29],[1563,1124,439],[388,324,64],[345,290,55],[694,662,32],[708,669,39],[1073,279,794],[1743,1584,159],[1168,1044,124],[623,550,73],[592,302,290],[640,582,58],[375,275,100],[257,147,110],[576,507,69],[719,658,61],[279,186,93],[473,300,173],[618,518,100],[335,292,43],[240,182,58],[318,293,25],[249,15,234],[793,608,185],[1678,1633,45],[418,383,35],[442,254,188],[961,832,129],[388,17,371],[2356,1858,498],[484,463,21
# ...

# %% [markdown]
# ## 1.是否擁有最多設備的學校都在同一區

# %% [markdown]
# ## 2.是否新設備會集中在某一區

# %% [markdown]
# ## 3.設備的多寡 會跟學校所在地有關嗎?
